# %% [markdown]
# # <center>Web Scraping II -- Dyamic Web Page Scraping with Selenium </center>
#
# References:
# - http://selenium-python.readthedocs.io/getting-started.html
# - https://www.scrapingbee.com/blog/selenium-python/

# %% [markdown]
# ## 1. Why Selenium
# - So far, we have learned how to scrape **static** HTML pages using **Requests + BeautifulSoup**
# - However, if the web content relies on **javascript or AJAX** to build the content, this combination does not work
#   - Elements in a web page loaded **asynchronously**
#      * while requests.get(url) can only return the initial content
#      * you may need to wait for a while to get web content fully loaded
#   - You need to **interact with the page** to get some content loaded, e.g.
#      * scroll down to load more
#      * click a button like "more"
#      * fill a form
# - Example: https://www.quora.com/topic/Machine-Learning

# %%
# Exercise 1.1. Scape quora page using requests+beautifulsoup

# import requests package
import requests                   

# import BeautifulSoup from package bs4 (i.e. beautifulsoup4)
from bs4 import BeautifulSoup   

page = requests.get("https://www.quora.com/topic/Machine-Learning")    # send a get request to the web page

if page.status_code==200:      

    soup = BeautifulSoup(page.content, 'html.parser')
    
    # get all questions
    questions=soup.select("span.q-box.qu-userSelect--text")
    
    for i, q in enumerate(questions):
        print(i, q.get_text())
        print("\n")
    
# Note: nothing is returned. Do you know why?

# %% [markdown]
# ## 2. Selenium WebDriver
# - Selenium WebDriver is one of the most popular tools for **Web UI Automation**
# - It uses the WebDriver protocol to control a web browser, like Chrome, Firefox or Safari.
# - Selenium is really useful when you have to perform action on a website such as:
#   - clicking on buttons
#   - filling forms
#   - scrolling
#   - taking a screenshot
#   - execute Javascript code.
# - Installation:
#   - Install Selenium package:
#     - pip install selenium
#   - Download a webdirver based on your browser: https://www.selenium.dev/documentation/en/getting_started_with_webdriver/third_party_drivers_and_plugins/. `Be sure to download the latest version!`
#   - Place the webdrive (unzip it if the download is zipped) in a folder, e.g. a sub-folder called `drive` under the current working folder. When call selenium, point the `executable_path` parameter to that folder, i.e. `driver = webdriver.Firefox(executable_path='driver/geckodriver')`
#   - Here we use **Firefox**

# %% [markdown]
# ## 3. Use of Selenium WebDriver
#
# ### 3.1. **Navigating** (similar to beautifulsoup, but using different syntax)
#   * navigate to a link
#   * find elements by id, name, xpath, CSS selectors
#     * check this for detailed syntax: https://www.selenium.dev/documentation/en/getting_started_with_webdriver/locating_elements/
#
# |    | requests/BeautifulSoup | Selenium WebDriver |
# | -- |:------------------      |:-----------|
# | Navigate to a link |   `requests.get(url)`           | `driver.get(url)`    |
# | find elements  | `soup.select()` | `driver.find_element_by_id()`<br> `driver.find_element_by_tag_name()` <br> `find_element_by_css_selector()`, <br> ...|
# | get attributes of <br>element (say `p`) | `p.attrs` <br>    `p["class"]` | `p.get_attribute("class")` |
# | get tag name | `p.name` | `p.tag_name` |

# %%
# Exercise 3.1.1 Scrape using Selenium

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions 

# for Firefox browser, do the following
# (1) find the path where you save the webdriver 
executable_path = 'driver/geckodriver'
# (2) initial the driver
driver = webdriver.Firefox(executable_path=executable_path)

# Selenium is built in in Safari
# Make sure you enable "Develop -> Allow Remote Automation"
#driver = webdriver.Safari()

# send a request
driver.get('https://www.quora.com/topic/Machine-Learning')

# you should see a Firefox window open

# %%
# Exercise 3.1.2. Select truncated text using Selenium

# get all questions using css selector
questions=driver.\
   find_elements_by_css_selector("span.q-box.qu-userSelect--text")
    
for i, q in enumerate(questions):
    print(i, q.text)
    print("\n")
    
# close the webdriver. The firefox window closes
driver.quit()
# Out:
# 0 Is it worth doing the Machine Learning Crash Course by Google or is Andrew Ng’s Coursera course better?
#
#
# 1 I took the ML on Coursera more than a half year ago. After Google released their ML resource, I went to check them out and found the ML crash course. It looked quite interesting. So I went through the Crash Course and tried to get an idea what was going on right there. Let me point out couple of the
#
#
# 2 What are the critical data science skills that you find are lacking in online data science/ML courses or traditional university ML programs and courses?
#
#
# 3 As a current Master's student in Statistics / Data Science at Stanford University, there are three skill areas that immediately come to mind that can't really be learned in a large-classroom or online-course format. * Pragmatism and prioritization, particularly when it comes to knowing what ideas are w
#
#
# 4 What is the future of data science?
#
#
# 5 The Future of Data Science The digital age we live in is changing the way that we work, play, and learn. For organisations striving to achieve digital transformation, or behave more competitively through data analytics, becoming data-driven is a key goal. The progress in achieving this goal is dishea
#
#
# 6 What are some common errors in machine learning caused by poor knowledge of statistics?
#
#
# 7 The most common and basic mistake which I saw people with poor knowledge of statistics make is to apply different ML tools on data without understanding the importance of dimensionality constant and data’s probability distribution. 1. Dimensionality constant and the Curse of Dimensionality: Dimension
#
#
# 8 What is the future of TensorFlow?
#
#
# 9 Future? There is no future for TensorFlow. Everybody who have used it knows that it was designed wrong from the very beginning. It was heavily influenced by the now-obsolete Theano, and inherited the same design logic of static graphs, but with much better systems efforts led by the legendary Jeff D
#
#
# 10 If I am a beginner at machine learning and my current goal is publish a good paper within 6 month how should I start with considering I have no experience in publications and what ML topic I should pick in 2020?
#
#
# 11 Ok, before I answer your interesting question, let me rephrase it in terms of another activity that I just started doing myself: exercising. I was *really* out of shape for a long while, partly because I was too obsessed with doing research to pay attention to my health, and partly due to some surger
#
#
# 12 What are the dark sides of a career in AI/machine learning?
#
#
# 13 I’m not sure if I’d call it a “dark side” but there is likely to be a bit of disillusionment for most people when they go for a career in AI. Here are some reasons. 1. It’s really, really hard to build AI-based software products. It’s actually really hard to build any software products especially for pe
#
#
# 14 How does the AI in Tesla distinguish between a large hole in the road or a dark stain on the road?
#
#
# 15 Question from Chris Gunson—Thanks for asking the question, Chris! ^ How does a car AI system tell these apart? The third one is potentially dangerous. The others… not so much. What about when you add shadows into the equation—what then? ^ Dark shadows and stains may appear like…or obscure…potholes. The
#
#
# 16 What's next after deep learning?
#
#
# 17 The first, and most important thing, to realize about deep learning is that it is not a “deep” subject, meaning that it is a very “shallow” topic with almost no theory underlying it. There are no guarantees of convergence (since we are after all talking about nonlinear optimization in high-dimension
#
#
# 18 What is the brutal truth about machine learning?
#
#
# 19 Not really brutal but more of anti-climactic realities: * Most business datasets are either too dirty or too sparse to make machine learning useful. * The actual use-cases for machine learning are few vs. more general business analytics. Many business problems do not require prediction. Inferential statis

# %% [markdown]
# ### 3.2. Simulates users' actions performed in a web browser.
#
#   - click a button
#     * e.g. submit_button.click()
#   - fill a form
#     * e.g. text_box.send_keys("enter some text")
#   - scroll page down or up
#     * e.g. body.send_keys(Keys.PAGE_DOWN)
#   - move between windows and frames
#     * e.g. driver.switch_to_frame("frameName")
#   ...
#   - For details see https://selenium-python.readthedocs.io/navigating.html

# %%
# 3.2.1 Simulate "click"
# Click "more" link to get full answer

driver = webdriver.Firefox(executable_path=executable_path)

driver.get('https://www.quora.com/topic/Machine-Learning')

driver.implicitly_wait(10)  # set implict wait

# locate a "more" link by css selector
more_link=driver.\
find_element_by_css_selector("div.q-text.qu-cursor--pointer.qt_read_more")

# click the link element
more_link.click()

# Check firefox browser to see an expanded answer

# %%
driver.quit()

# %%
# Scroll down to load more questions
import time

driver = webdriver.Firefox(executable_path=executable_path)

driver.get('https://www.quora.com/topic/Machine-Learning')

# scroll down 5 times
for i in range(5):
    driver.execute_script("window.scrollTo(0, \
    document.body.scrollHeight);")
    
    # wait for the content to be loaded
    time.sleep(2)   

questions=driver.\
   find_elements_by_css_selector("span.q-box.qu-userSelect--text")
    
for i, q in enumerate(questions):
    print(i, q.text)
    print("\n")
# Out:
# 0 Is it worth doing the Machine Learning Crash Course by Google or is Andrew Ng’s Coursera course better?
#
#
# 1 I took the ML on Coursera more than a half year ago. After Google released their ML resource, I went to check them out and found the ML crash course. It looked quite interesting. So I went through the Crash Course and tried to get an idea what was going on right there. Let me point out couple of the
#
#
# 2 What are the critical data science skills that you find are lacking in online data science/ML courses or traditional university ML programs and courses?
#
#
# 3 As a current Master's student in Statistics / Data Science at Stanford University, there are three skill areas that immediately come to mind that can't really be learned in a large-classroom or online-course format. * Pragmatism and prioritization, particularly when it comes to knowing what ideas are w
#
#
# 4 What is the future of data science?
#
#
# 5 The Future of Data Science The digital age we live in is changing the way that we work, play, and learn. For organisations striving to achieve digital transformation, or behave more competitively through data analytics, becoming data-driven is a key goal. The progress in achieving this goal is dishea
#
#
# 6 What do you think is the most clever machine learning algorithm?
#
#
# 7 t-SNE Halfway through reading the paper on this, I reflexively blurted out “How the fuck did anyone think of this?” It takes some serious smarts to get me to audibly curse in a room full of strangers. First, let’s state a specific problem this monster solves. I give you a set of high dimensional point
#
#
# 8 What are some common errors in machine learning caused by poor knowledge of statistics?
#
#
# 9 The most common and basic mistake which I saw people with poor knowledge of statistics make is to apply different ML tools on data without understanding the importance of dimensionality constant and data’s probability distribution. 1. Dimensionality constant and the Curse of Dimensionality: Dimension
#
#
# 10 What is the future of TensorFlow?
#
#
# 11 Future? There is no future for TensorFlow. Everybody who have used it knows that it was designed wrong from the very beginning. It was heavily influenced by the now-obsolete Theano, and inherited the same design logic of static graphs, but with much better systems efforts led by the legendary Jeff D
#
#
# 12 If I am a beginner at machine learning and my current goal is publish a good paper within 6 month how should I start with considering I have no experience in publications and what ML topic I should pick in 2020?
#
#
# 13 Ok, before I answer your interesting question, let me rephrase it in terms of another activity that I just started doing myself: exercising. I was *really* out of shape for a long while, partly because I was too obsessed with doing research to pay attention to my health, and partly due to some surger
#
#
# 14 What are the dark sides of a career in AI/machine learning?
#
#
# 15 I’m not sure if I’d call it a “dark side” but there is likely to be a bit of disillusionment for most people when they go for a career in AI. Here are some reasons. 1. It’s really, really hard to build AI-based software products. It’s actually really hard to build any software products especially for pe
#
#
# 16 How does the AI in Tesla distinguish between a large hole in the road or a dark stain on the road?
#
#
# 17 Question from Chris Gunson—Thanks for asking the question, Chris! ^ How does a car AI system tell these apart? The third one is potentially dangerous. The others… not so much. What about when you add shadows into the equation—what then? ^ Dark shadows and stains may appear like…or obscure…potholes. The
#
#
# 18 What's next after deep learning?
#
#
# 19 The first, and most important thing, to realize about deep learning is that it is not a “deep” subject, meaning that it is a very “shallow” topic with almost no theory underlying it. There are no guarantees of convergence (since we are after all talking about nonlinear optimization in high-dimension
#
#
# 20 What is the brutal truth about machine learning?
#
#
# 21 Not really brutal but more of anti-climactic realities: * Most business datasets are either too dirty or too sparse to make machine learning useful. * The actual use-cases for machine learning are few vs. more general business analytics. Many business problems do not require prediction. Inferential statis
#
#
# 22 Why is logistic regression considered a linear model?
#
#
# 23 Why is logistic regression considered a linear model? The short answer is: Logistic regression is considered a generalized linear model because the outcome always depends on the sum of the inputs and parameters. Or in other words, the output cannot depend on the product (or quotient, etc.) of its par
#
#
# 24 What is a step-by-step plan for mastering machine learning?
#
#
# 25 1. Set some realistic expectations. Skip the boot camps, you can’t learn shit in 2 weeks or 2 months. 2. Machine learning engineers are programmers. You’ll need to know Python and the core ML libs. You’ll also need to know SQL and a big data suite. Start learning core Python and Pandas first. Skip Keras an
#
#
# 26 What have you gained from working in a group?
#
#
# 27 In Iowa, we have a state-wide competition we call “Speech Contest”, where you can compete in a variety of group events or compete in a variety of individual events. For 3 years in a row, I competed in an improvisation group. We were a pretty diverse group of students (besides our race that is, but in
#
#
# 28 Why did Google make highly valuable proprietary technology like TensorFlow and Kubernetes public and available to competitors as open source even though it still mainly funds and does the vast majority of continued development of those projects?
#
#
# 29 Kubernetes solves a major business problem for Google… they fucked up their cloud strategy and now they have to fix it. DISCLAIMER: I have not worked for Google since April 2013. Google could have jumped into the Cloud business as early at 2008. I say this because that’s when I personally asked Sergey
#
#
# 30 What is a data scientist interview at Google like?
#
#
# 31 For starters, let’s look at some of the minimum qualifications that you’re expected to have to apply for a data scientist job at Google: * Master's degree in a quantitative discipline (e.g., Statistics, Operations Research, Bioinformatics, Economics, Computational Biology, Computer Science) or equivale
#
#
# 32 Should I learn deep learning or concentrate on other areas of machine learning? What is better for a future career?
#
#
# 33 I can only answer this question from my personal experience, of someone who has spent the better part of his life studying machine learning. I wrote my first machine learning program in 1981, inspired by Doug Hofstadter’s classic book on Godel, Escher and Bach, which introduced me to the field. My f
#
#
# 34 Why do some scientists say that AI could be worse than extinction?
#
#
# 35 Well, a rogue AI could decide to enslave us all - maybe it would decide that it’s immoral to outright kill the excessive number of humans on this tiny planet - but it’s OK to starve them to death. Did you ever watch the movie “The Matrix”? We’re trying to imagine a situation with an AI that’s smarter
#
#
# 36 What is something about the field of data science that only a professional would know?
#
#
# 37 No one taught this in school: * There's a lot less hand math than you would expect. There's more coding, data-prep and problem solving than hand math. * What HR usually looks for, isn't what the hiring manager needs. * The sexy algorithms are the smallest part of the process vs. data-prep, problem definition
#
#
# 38 What are the dangers of using machine learning libraries without any understanding?
#
#
# 39 Here’s a picture of a cat right? Google’s Inception model thinks it’s a guacamole. As much as the image looks like a cat, the image is digitally altered which confused the model. Slightly rotating the image led the model to correctly classify the image as a cat (and as an animal). The above image is w
#
#
# 40 What data science or machine learning problem are you trying to solve right now?
#
#
# 41 Right at this moment (3:40 pm CST on October 29, 2018) I'm working on a rather theoretical problem. Let me set the stage for it. Most people familiar with machine learning know the gradient descent algorithm as a way to optimize machine learning models. Virtually all machine learning problems can be c
#
#
# 42 Is machine learning currently overhyped?
#
#
# 43 I would definitely say so. In my last 3 jobs as both a data science manager and data scientist, I’ve tried to use machine learning but in each job it is the same story. The company states in the job description they want somebody with ML knowledge and the know-how to apply ML to solve current problem
#
#
# 44 Is Andrew Ng's Machine Learning course still the best machine learning course available?
#
#
# 45 Nobody mentioned Pedro Domingos’s ML course on Coursera? (Pedro is a professor at Univ. of Washington, and one of the most cited researchers in ML). I think it’s a lot better than Andrew Ng’s as a first course on ML. I myself benefited a lot from Pedro’s course when preparing my own lectures. The mai
#
#
# 46 Does every paper in machine learning introduce a new algorithm?
#
#
# 47 Sadly, yes, and therein lies one of the deepest problems with the field right now. By my conservative estimate, more than 10,000 papers are published in ML every year (roughly say 30 per day), and almost every paper without exception introduces a new algorithm. Heck, I’m as guilty of this sin as the
#
#
# 48 What is the weirdest thing a neural network has done?
#
#
# 49 A deep neural network that’s well trained for image recognition at near-human level can be fooled by very small but carefully crafted perturbations (even by one pixel)[1710.08864] One pixel attack for fooling deep neural networks in the image that are imperceptible to human eyes. These are called a
#
#
# 50 Is Machine Learning just glorified statistics?
#
#
# 51 I used to think so when I visited the Machine Learning Department at CMU because people used to use “machine learning” to refer to statistical machine learning. But in fact, ML “steals” good ideas from a variety of fields, e.g. control theory, statistics, information theory, mathematical optimizatio
#
#
# 52 Can I get a machine learning job if I finish Andrew Ng's Deep Learning Specialization?
#
#
# 53 Put yourself in your future boss shoes: can you do a project? Andrew Ng courses are a public service. The style is engaging, the content well motivated, and he does not hide the maths - without being hard to follow. But it's like watching a Chef doing one of his famous recipe on TV. Very exciting, it
#
#
# 54 How much Machine Learning is needed for becoming a Data scientist?
#
#
# 55 When I am hiring a data scientist, I expect them to understand clearly, and able to implement the following: 1. Pre-processing: Able to clean the data in a meaningful, reduce the dimensionality and extract relevant features for the problems they are tackling. 2. Models and algorithms: understand supervised
#
#
# 56 Andrew Ng's courses are old and I'm not sure if they’re useful now. So what's the best course for beginners on Machine Learning in 2018?
#
#
# 57 I enrolled to most ML courses of Andrew Ng and also a lot of other online courses from different trainers. The difference I found is very simple: * Do you want to play around with some ML models in TF, Keras, whatsoever? Go for any of the online courses that you will find. These will provide plenty of
#
#
# 58 As a machine learning and deep learning beginner, should I focus on "getting the shit done" or learn the maths and algorithms thoroughly?
#
#
# 59 If you are into proving concepts then learn the maths and algorithms thoroughly. I am sure you don't need to be an expert in programming so algorithms here means those algorithms in machine learning (ML) and deep learning (DL). The foundation you setup is dependent on what you want to build on it la
#
#
# 60 Is AI/ML all about mathematics? If you take out the infrastructure required to handle computation, I find AI to be mostly computational maths. Do things like greedy algorithms, sorting and other cool CS things get applied here?
#
#
# 61 When I got into ML, I thought that it will be really easy, just to learn about the use cases for every algorithm, optimization methods and that’s it. That was really dumb of me. My biggest regret is that I didn’t learn more math earlier. More discrete math, more linear algebra, functional analysis, re
#
#
# 62 If you had to interview someone for a data science position, what questions would you ask them to establish their competence?
#
#
# 63 I’ve interviewed over 100 candidates for sundry machine learning jobs in the Atlanta area. We start with a canned phone screen. It’s all SQL and Pandas. If you can’t source and wrangle your own data we can’t use you regardless of your other qualifications. Actually, Google has identified SQL as the nu
#
#
# 64 Is there a reason why top universities like MIT, Berkeley, and Stanford, etc. don't do that much deep learning?
#
#
# 65 There actually is something of a reason that MIT doesn’t teach much of deep learning. There is currently one week-long class offered specifically on that subject by itself, 6.S191 Introduction to Deep Learning, and I believe it has only been offered once. Other classes in machine learning very brief
#
#
# 66 What's the most ingenious use of machine learning?
#
#
# 67 The most ingenious? I am not sure you can find two who agree on any, but one of the most ingenious uses was by Paul Depodesta back in the early noughties, and has since revolutionised many sports in ways intangible to most of us, since they are mainly related to team management. It was even populari
#
#
# 68 If I were to create a non-biased fake news Google Chrome extension detector using Machine Learning, would people use it? Would people get offended if the learning algorithm give them “unexpected” results?
#
#
# 69 Not only would people use it, you would likely become very wealthy and probably get a Turing Award. The problem, you see, is not building a detector using a machine learning model, but in defining what “fake news” is in a non-biased way. Your detector is going to have to be (artificially) intelligent
#
#
# 70 Is it enough to complete a machine learning course by Andrew Ng from Coursera to get my first job/internship? If not, what more can be done for the same?
#
#
# 71 (Thanks for ask4answer.) Well, in recent weeks two people I interviewed for the machine learning position at our company mentioned they've completed Andrew Ng's Coursera course. In the end, I didn't hire either of them. It was for other reasons (mainly they weren't so good in thinking about algorithm
#
#
# 72 Why there are so much misleading information on Quora get upvotes eg: becoming a ML engineer doesn't require understand ml algorithm, while in reality if you can't explain an algorithm in an interview you are doomed, what can we do to help this?
#
#
# 73 My boss at Google took a course in ML there, done by the people who worked on Tensor Flow. He said that in the course, they didn’t teach him the algorithms. They didn’t teach him the details, just enough to get him interested to “play with it”. And, I think there is a lot of ML like that. People wan
#
#
# 74 What are some common red flags you've noticed when you are reviewing a Data Scientist candidate's GitHub?
#
#
# 75 I have never reviewed anybody's GitHub, but mine got reviewed at one of the interview stages for my current position. When I got the position, they told me what they were specifically looking for, which apparently is an intergral part of my code writing style, and is as follows: 1. Commenting/Annotat
#
#
# 76 What programming languages and frameworks are fitted for a web app that makes a heavy use of custom artificial intelligence algorithms?
#
#
# 77 When it comes to AI it is a good idea to rely on PyTorch or TensorFlow. You can use Python, shall probably. Use the Django framework or Fast API. Maybe Flask if you plan to not to use the ORM or such tools. If you create a lot of AI related custom code you can write it in Python with Numpy and later m
#
#
# 78 Does AlphaZero defeating the best chess player only goes to show that chess is not really a game of intelligence as falsely perceived?
# 79 “Game of intelligence” is a bogus term; chess is a game of strategy and skill. “Intelligence”, if that word is to mean anything at all, is an absolutely terrible predictor of chess skill. Most of the people you would consider very intelligent, on any basis other than chess itself, don’t play the gam
#
#
# 80 Is machine learning the hardest degree to undertake?
#
#
# 81 During my PhD time, there was this Chinese undergrad (later became a masters student and now a PhD student), who would solve any damn machine learning problem so easily. He was a genius, for him I am sure, being anything was possible. I was awe struck. When you start (or about to start) something, it
#
#
# 82 How does a typical day for someone working in Machine Learning look like?
#
#
# 83 * Wake up. * Stumble into the office. * Mess around with some completely useless proof-of-concept in Jupyter Notebook that will never see the light of day in production. * Go for a good, long lunch. * Hang around the coffee machine and discuss the strengths and weaknesses of deep learning frameworks you’ve never
#
#
# 84 Is it worth it to get a PhD in ML or will a Masters suffice?
#
#
# 85 What’s your end goal? Do you want to do research or teach? If you want to be a machine learning engineer in the real world skip the master’s and the Phd and learn data wrangling skills and Python. In the real world machine learning is programming. Here are some real world insights for you. 1. Most of my tim
#
#
# 86 Can a CS PhD with experience in Machine learning, optimization, linear algebra and statistics make a shift to a quant position in finance?
#
#
# 87 No. Not at all. You at least require a CS PhD with experience in ML, optimization, linear algebra, statistics and a MSc in Economics before you qualify as even “eligible enough” to apply for a quant role. I honestly fine these troll questions. Look, most job requirements you see online for a role are
#
#
# 88 Why is deep learning so easy?
#
#
# 89 I can perfectly understand why one might think so. If you’re learning Deep Learning on your own, then chances are you’re following one of those online courses. I’ve been doing a few of those myself. Here’s why doing courses such as those might make Deep Learning “seemingly” easy: * Firstly, a lot of the
#
#
# 90 Is freelance work related to machine learning applications as abundant as web development and web design?
#
#
# 91 Not really. In my experience, there are two main reasons. 1.) Demand and Cost While machine learning is becoming more widespread, demand still lags behind fields like web development. This is especially apparent when you look at small and medium-sized companies. Almost every business wants a website t
#
#
# 92 Has machine learning evolved in the past half-decade?
#
#
# 93 It has evolved like crazy, especially in the field of deep learning. Let me just give you two examples. Transformers Since 2017 we’ve seen the rise of transformer architectures. This is a new type of neural network architecture for handling sequential data such as text, speech, etc. Up until 2017, LST
#
#
# 94 Why is deep learning so easy?
#
#
# 95 I wondered the same thing half an hour after learning what a neural network was. My background was an MS in pure math, so everything made perfect sense. 1. Specify a structure and a loss function to optimize. 2. Optimize it using gradient descent. a. The network feeds forward with just matrix multiplication and
#
#
# 96 What are the biggest misconceptions people have about data science?
#
#
# 97 You could turn this post into a book. Here are a few. 1. This job is all about building machine learning models. Hell no. Modeling is a small part of the job and getting smaller with the accuracy of AutoML. 2. Someone else will source and clean my data. Not in the real-world. If you can’t source and clean yo
#
#
# 98 How well do machine learning researchers need to code?
#
#
# 99 Not too well. A machine learning researcher shouldn’t code as well as someone like myself, for instance. And I say that not to brag. Here’s why: 1. A machine learning researcher who codes really well has simply spent too much time coding and not enough time doing research. It takes practice to get to a h

# %%
driver.quit()

# %% [markdown]
# ### 3.3. Wait
#   - Because of the use of AJAX technologies, web elements often load at different time intervals.
#   - This makes locating elements difficult.
#     - if an element is not loaded,  a locating function will raise an ElementNotVisibleException exception.
#   - Two types of waits
#     - `implicit`: When a Webdriver locates for any element, but the element is not available, instead of throwing "No Such Element Exception" immediately, the Webdriver waits for a certain amount of time. By the time it is still not available, then the error is thrown.
#       * Implicit wait is set at the driver level and applies to any locating function
#     - `explicit`: WebDriver waits for a certain condition to occur before proceeding further with execution
#       * Explicit wait is set at each locating function

# %% [markdown]
# Assume you're looking for a question `How should you start a career in Machine Learning?`, but you're not sure if this question has been loaded into the page
# - Case 1: If this question is not in the page, you get an error immediately
# - Case 2: If it takes time to load the question, use implict wait to wait for some time
# - Case 3: You can keep scroll down until the question has been loaded or max tries reached
#     - Use `try ... else` block to handle the exception more elegently

# %%
# If the element is not there, you'll see an error immediately

#driver = webdriver.Safari()
driver = webdriver.Firefox(executable_path=executable_path)
driver.get('https://www.quora.com/topic/Machine-Learning')

q = driver.find_element_by_css_selector('a[href="/How-should-you-start-a-career-in-Machine-Learning"]')

print(q.text)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-36-6529fd963d5c> in <module>
#       5 driver.get('https://www.quora.com/topic/Machine-Learning')
#       6
# ----> 7 q = driver.find_element_by_css_selector('a[href="/How-should-you-start-a-career-in-Machine-Learning"]')
#       8
#       9 print(q.text)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: Unable to locate element: a[href="/How-should-you-start-a-career-in-Machine-Learning"]

# %%
# If the element is not there, you'll see an error after the waiting

driver = webdriver.Firefox(executable_path=executable_path)
driver.get('https://www.quora.com/topic/Machine-Learning')

driver.implicitly_wait(10)

q = driver.find_element_by_css_selector('a[href="/How-should-you-start-a-career-in-Machine-Learning"]')

print(q.text)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-37-0f45e9db69fa> in <module>
#       6 driver.implicitly_wait(10)
#       7
# ----> 8 q = driver.find_element_by_css_selector('a[href="/How-should-you-start-a-career-in-Machine-Learning"]')
#       9
#      10 print(q.text)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: Unable to locate element: a[href="/How-should-you-start-a-career-in-Machine-Learning"]

# %%
# If the element is not there, 
# you keep scrolling down until the element is there
# or scrolling for max number of times
# try except can catch the error

driver = webdriver.Firefox(executable_path=executable_path)
driver.get('https://www.quora.com/topic/Machine-Learning')

found = False
max_try = 10  # max number of scroll-downs
cnt = 0

while not found and cnt < max_try:
    
    try:
        # This waits up to 5 seconds before throwing a TimeoutException 
        # unless it finds the element to return within 10 seconds.
        
        q = WebDriverWait(driver,5).until(\
                    expected_conditions.\
                    presence_of_element_located((By.CSS_SELECTOR, \
                    'a[href="/How-should-you-start-a-career-in-Machine-Learning"]')))
        found = True
        print(q.text)

    except:     # item not there yet
        
        driver.execute_script("window.scrollTo(0, \
        document.body.scrollHeight);")
     
        cnt += 1
        
driver.quit()
